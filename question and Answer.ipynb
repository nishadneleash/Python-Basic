# %% [raw]
# 1. What is Python, and why is it popular
# ans: python is high level, general purpos progrmming.
# *ssimple and readable
# *easy to learn data structure.
# it is popular because
# beginer friendly, vesatile, huge community and large library support and cross platform.
#
#
#
# 2. What is an interpreter in Python
# ans: An interpreter translate python progrma written by programmer into machine language line by line and executes the code.
# no need to compile the prgrame in python.
#
#
#
# 3.What are pre-defined keywords in Python
# ans: pre-defined keyword are reserved keywords in python which cannot be used as variables, identifiers, function names in python.
#
# example: false , true, for , while , break , try
#
# 4.Can keywords be used as variable names
# ans: no we cannot use the variable names as keyword in python. it will give an syntax error.
#
# 5.What is mutability in Python
# ans: mutability refers that wheather or not an object can be changed after its created.
#
# mutable: can be changed ex: list,dict
# immutable: cannot be changed ex: str, tuple
#
#
# 6. Why are lists mutable, but tuples are immutable
# ans: list are mutable beacuse : python allow us to change once list is created. list are flexiable and can be changed after creation.
#      tuple are immutable because: In python there aare some sensitive data that cannot be changed after creation. because we need fixed and reliable data. it improves safety and performance.
#
#
# 7.What is the difference between “==” and “is” operators in Python
# ans: "==" means equality example a==b
#      "is" means memory location in python it can be same bur with different location.
#       Ex: a=(1,2,3) and b =(1,2,3) same but diffrent memory location
#
# 8.What are logical operators in Python
# ans: logical operator in python are used to cobine or compare multiple conditionss for decision making.
# logical and , logical or , logical and
#
# 9. What is type casting in Python
# type casting in python means converting one data type to another like str to int and float.
#
# 10.What is the difference between implicit and explicit type casting
# ans: python automatically converts data type is inplicit type casting.
#      in python if we manually convert data type than its explicit typecasting . we control the data type.
#
# 11.What is the purpose of conditional statements in Python
# Conditional statements in Python are used to make decisions in your program.
# They allow your code to perform different actions based on whether a condition is True or False.
# ex: if elif else
# it contraol the execution flow depending on contions given.
#
# 12.How does the elif statement work
# Python checks the first if condition.
# If True, it runs that block and skips the rest.
# If False, it checks the elif conditions in order.
# If none of them are true, it runs the else block.
#
# syntax:
# if condition1:
#     # Runs if condition1 is True
# elif condition2:
#     # Runs if condition1 is False AND condition2 is True
# elif condition3:
#     # Runs if all above are False and condition3 is True
# else:
#     # Runs if none of the above conditions are True
#
# 13.What is the difference between for and while loops
# For Loop:
# Use case : When you know how many times to loop
# Structure: Loops over a sequence ex: range
# Example:    for i in range(5):
# Stops when: Sequence is finished
#
# while Loop:
#  Use case : When you don’t know how many times
#   Structure:   Loops as long as a condition is True
#  Example:    while i < 5:
# Stops when:     while i < 5:
#
# 14.Describe a scenario where a while loop is more suitable than a for loop.
# A while loop is better when you don’t know in advance how many times you'll need to repeat something.
